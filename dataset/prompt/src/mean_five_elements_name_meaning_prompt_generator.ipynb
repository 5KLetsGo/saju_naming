# %% [markdown]
# # 자원오행을 해석하고 이를 보충할 수 있는 이름과 이름의 의미 prompt 제작

# %%
import pandas as pd

# %%
df_csv = pd.DataFrame(columns = [
    'question',
    'answer'
])

# %%
def name_mean_split(filename):
    name_mean_list = []
    name_mean_str = ''
    i = 0
    with open(f'./categorized_name_hanja_mean/{filename}.txt', 'r', encoding='utf-8') as f:
        while True:
            i += 1
            line = f.readline()
            name_mean_str += line
            if i == 14:
                name_mean_list.append(name_mean_str)
            elif i == 16:
                name_mean_str = ''
                i = 0
            if not line:
                break
    return name_mean_list

f_woodwood = name_mean_split('female_names_목목')
f_woodfire = name_mean_split('female_names_목화')
f_woodwater = name_mean_split('female_names_목수')
f_woodmetal = name_mean_split('female_names_목금')
f_woodearth = name_mean_split('female_names_목토')
f_firefire = name_mean_split('female_names_화화')
f_firewater = name_mean_split('female_names_화수')
f_firemetal = name_mean_split('female_names_화금')
f_fireearth = name_mean_split('female_names_화토')
f_waterwater = name_mean_split('female_names_수수')
f_watermetal = name_mean_split('female_names_수금')
f_waterearth = name_mean_split('female_names_수토')
f_metalmetal = name_mean_split('female_names_금금')
f_metalearth = name_mean_split('female_names_금토')
f_earthearth = name_mean_split('female_names_토토')

m_woodwood = name_mean_split('male_names_목목')
m_woodfire = name_mean_split('male_names_목화')
m_woodwater = name_mean_split('male_names_목수')
m_woodmetal = name_mean_split('male_names_목금')
m_woodearth = name_mean_split('male_names_목토')
m_firefire = name_mean_split('male_names_화화')
m_firewater = name_mean_split('male_names_화수')
m_firemetal = name_mean_split('male_names_화금')
m_fireearth = name_mean_split('male_names_화토')
m_waterwater = name_mean_split('male_names_수수')
m_watermetal = name_mean_split('male_names_수금')
m_waterearth = name_mean_split('male_names_수토')
m_metalmetal = name_mean_split('male_names_금금')
m_metalearth = name_mean_split('male_names_금토')
m_earthearth = name_mean_split('male_names_토토')

print(len(f_woodwater))
# Out:
# 6

# %%
index = 0
for name in m_woodwood:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 1개, 수는 1개, 토는 3개, 금은 1개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''목이 없는 사주입니다. 따라서 목을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 토가 강한 사주이기에 토를 상극하는 목을 하나 더 보충하는 것이 좋습니다. 즉, 목의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 목를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_firefire:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 0개, 수는 1개, 토는 1개, 금은 3개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''화가 없는 사주입니다. 따라서 화을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 금가 강한 사주이기에 토를 상극하는 목을 하나 더 보충하는 것이 좋습니다. 즉, 화의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 화를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_waterwater:
    df_csv.loc[index] =  ['''사주에 따른 자원오행이 목은 1개, 화는 3개, 수는 0개, 토는 1개, 금은 1개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                         f'''수가 없는 사주입니다. 따라서 수을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 화가 강한 사주이기에 토를 상극하는 목을 하나 더 보충하는 것이 좋습니다. 즉, 수의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 수를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_metalmetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 1개, 수는 2개, 토는 2개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''금이 없는 사주입니다. 따라서 금을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 수와 토가 강한 사주이기에 수를 상생시키고 토가 상생해주는 금을 보충하는 것이 좋습니다. 즉, 금의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 금를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_earthearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 2개, 수는 1개, 토는 0개, 금은 2개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''토가 없는 사주입니다. 따라서 토을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 화와 금이 강한 사주이기에 금을 상생시키고 화가 상생해주는 토를 보충하는 것이 좋습니다. 즉, 토의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 토를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_woodfire:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 0개, 수는 4개, 토는 2개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''수가 강하고 목, 화, 금은 없는 사주입니다. 따라서 목, 화, 금 중 두개를 보충하면 되는데 수를 상극하는 토를 이미 가지고 있기에 토를 상생시키는 화와 화를 상생시키는 목을 보충하는 것이 좋습니다. 즉, 화와 목의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 목과 화를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_woodwater:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 2개, 수는 0개, 토는 2개, 금은 2개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''목, 수가 없는 사주입니다. 따라서 목과 수의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 목과 수를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_woodmetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 3개, 수는 3개, 토는 0개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''화, 수가 강하고 목, 토, 금은 없는 사주입니다. 따라서 목, 토, 금 중에 두개를 보충하면 되는데 화를 상생시키는 목과 수를 상생시키는 금을 보충하는 것이 좋습니다. 즉, 목과 금의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 금과 목을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_woodearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 2개, 수는 3개, 토는 0개, 금은 1개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''목, 토가 없는 사주입니다. 따라서 목과 토의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 목과 토를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_firewater:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 0개, 수는 0개, 토는 4개, 금은 1개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''화, 수가 없는 사주입니다. 따라서 화와 수의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 화와 수를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_firemetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 4개, 화는 0개, 수는 0개, 토는 2개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''목이 강하고 화, 수, 금은 없는 사주입니다. 따라서 화, 수, 금 중 두개를 보충하면 되는데 목을 상극하는 금이 있으면 좋습니다. 그리고 금을 상생시키는 토가 있으면 좋은데, 이미 토를 가지고 있기에 토를 상생시키는 화를 보충하는 것이 좋습니다. 즉, 화와 금의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 화와 금을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_fireearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 0개, 수는 6개, 토는 0개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''수가 너무 강하고 목, 수, 토, 금은 없는 사주입니다. 따라서 수을 억제할 수 있는 토가 하나 필요합니다. 그리고 해당 토를 상생하는 화도 보충하면 좋습니다. 즉, 토와 화의 오행을 하나씩 보충하면 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 토와 화를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_watermetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 0개, 수는 0개, 토는 5개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''토가 너무 강하고 화, 수, 금은 없는 사주입니다. 따라서 화, 수, 금 중 두개를 보충하면 되는데, 토를 억제할 수 있는 목이 있으면 좋습니다. 이때, 이미 목을 가지고 있기 때문에 목을 상생할 수 있는 수를 보충하고 수를 상생시키는 금을 보충하는 것이 좋습니다. 즉 수와 금의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 수와 금을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_waterearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 1개, 수는 1개, 토는 1개, 금은 2개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''오행을 고루 가지고 있는 사주지만 자세히 보면 금이 강한 사주이기에 따라서 금을 상생시키는 토와 금이 상생해주는 수를 보충하는 것이 좋습니다. 즉, 수와 토의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 토와 수를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in m_metalearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 5개, 화는 0개, 수는 1개, 토는 0개, 금은 0개일 때, 이 사주를 보완하는 남자 이름 짓고 뜻 풀이해줘''',
                        f'''목이 너무 강하고 화, 토, 금은 없는 사주입니다. 따라서 목을 억제할 수 있는 금이 필요합니다. 그리고 해당 금를 상생시키는 토도 보충하면 좋습니다. 즉, 토와 금의 오행을 하나씩 보충하면 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 토와 금을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_woodwood:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 1개, 수는 1개, 토는 3개, 금은 1개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''목이 없는 사주입니다. 따라서 목을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 토가 강한 사주이기에 토를 상극하는 목을 하나 더 보충하는 것이 좋습니다. 즉, 목의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 목를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)
    
for name in f_firefire:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 0개, 수는 1개, 토는 1개, 금은 3개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''화가 없는 사주입니다. 따라서 화을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 금가 강한 사주이기에 토를 상극하는 목을 하나 더 보충하는 것이 좋습니다. 즉, 화의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 화를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_waterwater:
    df_csv.loc[index] =  ['''사주에 따른 자원오행이 목은 1개, 화는 3개, 수는 0개, 토는 1개, 금은 1개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                         f'''수가 없는 사주입니다. 따라서 수을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 화가 강한 사주이기에 토를 상극하는 목을 하나 더 보충하는 것이 좋습니다. 즉, 수의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 수를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_metalmetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 1개, 수는 2개, 토는 2개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''금이 없는 사주입니다. 따라서 금을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 수와 토가 강한 사주이기에 수를 상생시키고 토가 상생해주는 금을 보충하는 것이 좋습니다. 즉, 금의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 금를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_earthearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 2개, 수는 1개, 토는 0개, 금은 2개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''토가 없는 사주입니다. 따라서 토을 하나 보충하면 좋습니다. 그렇게 되면 오행을 고루 가지고 있게 되는데, 자세히 보면 화와 금이 강한 사주이기에 금을 상생시키고 화가 상생해주는 토를 보충하는 것이 좋습니다. 즉, 토의 오행을 두개 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 자원오행 토를 가지는 한자 두개를 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_woodfire:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 0개, 수는 4개, 토는 2개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''수가 강하고 목, 화, 금은 없는 사주입니다. 따라서 목, 화, 금 중 두개를 보충하면 되는데 수를 상극하는 토를 이미 가지고 있기에 토를 상생시키는 화와 화를 상생시키는 목을 보충하는 것이 좋습니다. 즉, 화와 목의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 목과 화를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_woodwater:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 2개, 수는 0개, 토는 2개, 금은 2개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''목, 수가 없는 사주입니다. 따라서 목과 수의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 목과 수를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_woodmetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 3개, 수는 3개, 토는 0개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''화, 수가 강하고 목, 토, 금은 없는 사주입니다. 따라서 목, 토, 금 중에 두개를 보충하면 되는데 화를 상생시키는 목과 수를 상생시키는 금을 보충하는 것이 좋습니다. 즉, 목과 금의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 금과 목을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_woodearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 2개, 수는 3개, 토는 0개, 금은 1개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''목, 토가 없는 사주입니다. 따라서 목과 토의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 목과 토를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_firewater:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 0개, 수는 0개, 토는 4개, 금은 1개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''화, 수가 없는 사주입니다. 따라서 화와 수의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 화와 수를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_firemetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 4개, 화는 0개, 수는 0개, 토는 2개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''목이 강하고 화, 수, 금은 없는 사주입니다. 따라서 화, 수, 금 중 두개를 보충하면 되는데 목을 상극하는 금이 있으면 좋습니다. 그리고 금을 상생시키는 토가 있으면 좋은데, 이미 토를 가지고 있기에 토를 상생시키는 화를 보충하는 것이 좋습니다. 즉, 화와 금의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 화와 금을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_fireearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 0개, 화는 0개, 수는 6개, 토는 0개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''수가 너무 강하고 목, 수, 토, 금은 없는 사주입니다. 따라서 수을 억제할 수 있는 토가 하나 필요합니다. 그리고 해당 토를 상생하는 화도 보충하면 좋습니다. 즉, 토와 화의 오행을 하나씩 보충하면 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 토와 화를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_watermetal:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 0개, 수는 0개, 토는 5개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''토가 너무 강하고 화, 수, 금은 없는 사주입니다. 따라서 화, 수, 금 중 두개를 보충하면 되는데, 토를 억제할 수 있는 목이 있으면 좋습니다. 이때, 이미 목을 가지고 있기 때문에 목을 상생할 수 있는 수를 보충하고 수를 상생시키는 금을 보충하는 것이 좋습니다. 즉 수와 금의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 수와 금을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_waterearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 1개, 화는 1개, 수는 1개, 토는 1개, 금은 2개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''오행을 고루 가지고 있는 사주지만 자세히 보면 금이 강한 사주이기에 따라서 금을 상생시키는 토와 금이 상생해주는 수를 보충하는 것이 좋습니다. 즉, 수와 토의 오행을 하나씩 보충하는 것이 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 토와 수를 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)

for name in f_metalearth:
    df_csv.loc[index] = ['''사주에 따른 자원오행이 목은 5개, 화는 0개, 수는 1개, 토는 0개, 금은 0개일 때, 이 사주를 보완하는 여자 이름 짓고 뜻 풀이해줘''',
                        f'''목이 너무 강하고 화, 토, 금은 없는 사주입니다. 따라서 목을 억제할 수 있는 금이 필요합니다. 그리고 해당 금를 상생시키는 토도 보충하면 좋습니다. 즉, 토와 금의 오행을 하나씩 보충하면 좋습니다. 이를 이용해 남자 이름을 짓게 되면 인명한자 중에 토와 금을 가지는 한자 하나씩을 이용해서 조합하면 됩니다.

이름 추천
{name}''']
    index += 1
print(index)
# Out:
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 66
# 72
# 78
# 84
# 90
# 96
# 102
# 108
# 114
# 120
# 126
# 132
# 138
# 144
# 150
# 156
# 162
# 168
# 174
# 180

# %%
df_csv.to_csv('../mean_five_elements_name_meaning_prompt.csv', index=False)
